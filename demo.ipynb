# %%
from azavea import City

c = City(name='Raleigh', admin='NC')
c
# Out:
# {'admin': 'NC', 'map_cell': {'coordinates': [281.375, 35.875], 'type': 'Point'}, 'name': 'Raleigh', 'population': 403892, 'region': 38}

# %%
for s in c.scenario():
    print(s['name'])
# Out:
# RCP45
# RCP85
# historical

# %%
for i in c.indicator():
    print(i['name'])
# Out:
# accumulated_freezing_degree_days
# average_high_temperature
# average_low_temperature
# cooling_degree_days
# diurnal_temperature_range
# extreme_cold_events
# extreme_heat_events
# extreme_precipitation_events
# frost_days
# heat_wave_duration_index
# heat_wave_incidents
# heating_degree_days
# max_high_temperature
# max_temperature_threshold
# min_low_temperature
# min_temperature_threshold
# percentile_high_temperature
# percentile_low_temperature
# percentile_precipitation
# precipitation_threshold
# total_precipitation
# yearly_dry_spells
# yearly_max_consecutive_dry_days

# %%
import matplotlib.pyplot as plt

plt.figure()
df = c.data('RCP45', 'max_high_temperature')
df.plot()
plt.show()
